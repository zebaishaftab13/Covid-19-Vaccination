# %% [markdown]
# #                    Analyzing Covid Vaccination Progress using Python
# Dataset Link :- https://covid19.who.int/who-data/vaccination-data.csv

# %%
#importing the necessary libraries like pandas,numpy,seaborn.matplotlib that are used for data analysis
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#reading the data using pandas read_csv function
data = pd.read_csv("C:/Users/DELL/Downloads/vaccination-data.csv")

# %%
#head() function shows the first five rows of the data
data.head()
# Out:
#           COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0     Afghanistan  AFG       EMRO   REPORTING   2022-05-23
# 1         Albania  ALB       EURO   REPORTING   2022-05-15
# 2         Algeria  DZA       AFRO   REPORTING   2022-05-22
# 3  American Samoa  ASM       WPRO   REPORTING   2022-05-12
# 4         Andorra  AND       EURO   REPORTING   2022-05-01
#
#    TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0           6118557.0                      5407462.0
# 1           2840948.0                      1302093.0
# 2          15205854.0                      7840131.0
# 3            108220.0                        44456.0
# 4            152694.0                        57874.0
#
#    TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 0                     15.717                                13.891
# 1                     98.700                                45.752
# 2                     34.676                                17.879
# ...

# %%
#tail() function shows the last five rows of the data
data.tail()
# Out:
#                COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 223           Viet Nam  VNM       WPRO   REPORTING   2022-05-19
# 224  Wallis and Futuna  WLF       WPRO   REPORTING   2022-04-14
# 225              Yemen  YEM       EMRO   REPORTING   2022-05-21
# 226             Zambia  ZMB       AFRO   REPORTING   2022-05-22
# 227           Zimbabwe  ZWE       AFRO   REPORTING   2022-05-22
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 223         218799777.0                     83637404.0
# 224             16426.0                         6592.0
# 225            836455.0                       670646.0
# 226           3750417.0                      4656681.0
# 227          10461256.0                      6113527.0
#
#      TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 223                    224.782                                85.924
# 224                    146.061                                58.616
# ...

# %%
#info() function is used to get the overview of data like data type of feature, a number of non-null values in each column and many more(object means string)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   COUNTRY                               228 non-null    object
#  1   ISO3                                  228 non-null    object
#  2   WHO_REGION                            228 non-null    object
#  3   DATA_SOURCE                           228 non-null    object
#  4   DATE_UPDATED                          228 non-null    object
#  5   TOTAL_VACCINATIONS                    227 non-null    float64
#  6   PERSONS_VACCINATED_1PLUS_DOSE         227 non-null    float64
#  7   TOTAL_VACCINATIONS_PER100             227 non-null    float64
#  8   PERSONS_VACCINATED_1PLUS_DOSE_PER100  227 non-null    float64
#  9   PERSONS_FULLY_VACCINATED              226 non-null    float64
#  10  PERSONS_FULLY_VACCINATED_PER100       226 non-null    float64
# ...

# %%
#gives the column names
data.columns
# Out:
# Index(['COUNTRY', 'ISO3', 'WHO_REGION', 'DATA_SOURCE', 'DATE_UPDATED',
#        'TOTAL_VACCINATIONS', 'PERSONS_VACCINATED_1PLUS_DOSE',
#        'TOTAL_VACCINATIONS_PER100', 'PERSONS_VACCINATED_1PLUS_DOSE_PER100',
#        'PERSONS_FULLY_VACCINATED', 'PERSONS_FULLY_VACCINATED_PER100',
#        'VACCINES_USED', 'FIRST_VACCINE_DATE', 'NUMBER_VACCINES_TYPES_USED',
#        'PERSONS_BOOSTER_ADD_DOSE', 'PERSONS_BOOSTER_ADD_DOSE_PER100'],
#       dtype='object')

# %%
#gives the number of rows and columns in the dataset
data.shape
# Out:
# (228, 16)

# %%
#isnull().sum() function gives the total count of null values in each feature
data.isnull().sum()
# Out:
# COUNTRY                                  0
# ISO3                                     0
# WHO_REGION                               0
# DATA_SOURCE                              0
# DATE_UPDATED                             0
# TOTAL_VACCINATIONS                       1
# PERSONS_VACCINATED_1PLUS_DOSE            1
# TOTAL_VACCINATIONS_PER100                1
# PERSONS_VACCINATED_1PLUS_DOSE_PER100     1
# PERSONS_FULLY_VACCINATED                 2
# PERSONS_FULLY_VACCINATED_PER100          2
# VACCINES_USED                            3
# FIRST_VACCINE_DATE                      21
# NUMBER_VACCINES_TYPES_USED               3
# PERSONS_BOOSTER_ADD_DOSE                33
# PERSONS_BOOSTER_ADD_DOSE_PER100         33
# dtype: int64

# %% [markdown]
# # DATA CLEANING

# %%
#handling and filling null values
data.fillna(value = 0, inplace = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   COUNTRY                               228 non-null    object
#  1   ISO3                                  228 non-null    object
#  2   WHO_REGION                            228 non-null    object
#  3   DATA_SOURCE                           228 non-null    object
#  4   DATE_UPDATED                          228 non-null    object
#  5   TOTAL_VACCINATIONS                    228 non-null    float64
#  6   PERSONS_VACCINATED_1PLUS_DOSE         228 non-null    float64
#  7   TOTAL_VACCINATIONS_PER100             228 non-null    float64
#  8   PERSONS_VACCINATED_1PLUS_DOSE_PER100  228 non-null    float64
#  9   PERSONS_FULLY_VACCINATED              228 non-null    float64
#  10  PERSONS_FULLY_VACCINATED_PER100       228 non-null    float64
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   COUNTRY                               228 non-null    object
#  1   ISO3                                  228 non-null    object
#  2   WHO_REGION                            228 non-null    object
#  3   DATA_SOURCE                           228 non-null    object
#  4   DATE_UPDATED                          228 non-null    object
#  5   TOTAL_VACCINATIONS                    228 non-null    float64
#  6   PERSONS_VACCINATED_1PLUS_DOSE         228 non-null    float64
#  7   TOTAL_VACCINATIONS_PER100             228 non-null    float64
#  8   PERSONS_VACCINATED_1PLUS_DOSE_PER100  228 non-null    float64
#  9   PERSONS_FULLY_VACCINATED              228 non-null    float64
#  10  PERSONS_FULLY_VACCINATED_PER100       228 non-null    float64
# ...

# %% [markdown]
# # DATA VISUALIZATION

# %%
#describe() function in pandas is used to get the statistics of each feature present in our dataset
data.describe()
# Out:
#        TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# count        2.280000e+02                   2.280000e+02
# mean         5.180538e+07                   2.277886e+07
# std          2.680771e+08                   1.127238e+08
# min          0.000000e+00                   0.000000e+00
# 25%          3.812865e+05                   1.863400e+05
# 50%          2.934532e+06                   2.044788e+06
# 75%          1.825446e+07                   8.179027e+06
# max          3.442313e+09                   1.313020e+09
#
#        TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# count                 228.000000                            228.000000
# mean                  133.420452                             58.065180
# std                    77.736177                             27.257862
# min                     0.000000                              0.000000
# 25%                    66.784500                             37.444750
# ...

# %%
#unique() function in pandas helps to get unique values present in the feature
data.COUNTRY.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bonaire',
#        'Bonaire, Sint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', 'Côte d’Ivoire',
#        'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czechia',
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
data.VACCINES_USED.unique()
# Out:
# array(['AstraZeneca - Vaxzevria,Beijing CNBG - BBIBP-CorV,Bharat - Covaxin,CanSino - Convidecia,Gamaleya - Gam-Covid-Vac,Gamaleya - Sputnik-Light,Janssen - Ad26.COV 2-S,Moderna - Spikevax,Pfizer BioNTech - Comirnaty,SII - Covishield,Sinovac - CoronaVac',
#        'AstraZeneca - Vaxzevria,Gamaleya - Gam-Covid-Vac,Pfizer BioNTech - Comirnaty,SII - Covishield,Sinovac - CoronaVac',
#        'Beijing CNBG - BBIBP-CorV,Gamaleya - Gam-Covid-Vac,SII - Covishield,Sinovac - CoronaVac',
#        'Janssen - Ad26.COV 2-S,Moderna - Spikevax,Pfizer BioNTech - Comirnaty',
#        'AstraZeneca - Vaxzevria,Moderna - Spikevax,Pfizer BioNTech - Comirnaty',
#        'SII - Covishield',
#        'AstraZeneca - Vaxzevria,Pfizer BioNTech - Comirnaty',
#        'AstraZeneca - Vaxzevria,Beijing CNBG - BBIBP-CorV,Gamaleya - Gam-Covid-Vac,Janssen - Ad26.COV 2-S,Pfizer BioNTech - Comirnaty,SII - Covishield',
# ...

# %%
#relplot() function provides access to several different axes level functions that shoe the relationship between two variables with semantic mapping of subsets
#by default it gives a scatter plot
sns.relplot(x="TOTAL_VACCINATIONS", y="PERSONS_VACCINATED_1PLUS_DOSE", data = data)

# %%
sns.relplot(x="TOTAL_VACCINATIONS_PER100", y="PERSONS_VACCINATED_1PLUS_DOSE_PER100", data = data)

# %%
sns.relplot(x="TOTAL_VACCINATIONS", y="PERSONS_FULLY_VACCINATED", data = data)

# %%
 sns.relplot(x="PERSONS_BOOSTER_ADD_DOSE", y= "PERSONS_BOOSTER_ADD_DOSE_PER100", data = data)

# %%
#pairplot() function plots a pairwise relationships in a dataset
sns.pairplot(data)

# %%
#plots a line graph
sns.relplot(x="TOTAL_VACCINATIONS", y="PERSONS_FULLY_VACCINATED", kind = "line", data = data)

# %%
sns.relplot(x="TOTAL_VACCINATIONS_PER100", y="PERSONS_VACCINATED_1PLUS_DOSE_PER100", kind = "line" ,data = data)

# %%
#catplot() function plots that involve categorical variables
sns.catplot(x="TOTAL_VACCINATIONS", y="PERSONS_VACCINATED_1PLUS_DOSE", data = data)
